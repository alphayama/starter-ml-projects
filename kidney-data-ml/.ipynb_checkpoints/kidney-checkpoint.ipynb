# %%
import xgboost as xgb
import pandas as pd
import numpy as np 
from sklearn import datasets
from sklearn.model_selection import train_test_split,GridSearchCV
from matplotlib import pyplot as plt
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import Imputer,StandardScaler,OneHotEncoder
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.svm import SVC
import xgboost as xgb

# %%
kd=pd.read_csv('./chronic_kidney_with_class.csv')

# %%
kd.head()
# Out:
#    Unnamed: 0 age  bp     sg al su     bgr        bu          sc         sod  \
# 0           0  48  80  1.020  1  0       ?    normal  notpresent  notpresent
# 1           1   7  50  1.020  4  0       ?    normal  notpresent  notpresent
# 2           2  62  80  1.010  2  3  normal    normal  notpresent  notpresent
# 3           3  48  70  1.005  4  0  normal  abnormal     present  notpresent
# 4           4  51  80  1.010  2  0  normal    normal  notpresent  notpresent
#
#    ...   pc   pcc   ba  htn   dm cad appet   pe  ane class
# 0  ...   44  7800  5.2  yes  yes  no  good   no   no   ckd
# 1  ...   38  6000    ?   no   no  no  good   no   no   ckd
# 2  ...   31  7500    ?   no  yes  no  poor   no  yes   ckd
# 3  ...   32  6700  3.9  yes   no  no  poor  yes  yes   ckd
# 4  ...   35  7300  4.6   no   no  no  good   no   no   ckd
#
# [5 rows x 26 columns]

# %%
kd.replace('?',np.nan,inplace=True)

# %%
kd.isnull().sum()
# Out:
# Unnamed: 0      0
# age             9
# bp             12
# sg             47
# al             46
# su             49
# bgr           152
# bu             65
# sc              4
# sod             4
# pot            44
# hemo           19
# pcv            17
# wc             87
# rc             88
# rbc            52
# pc             71
# pcc           106
# ba            131
# htn             2
# dm              2
# cad             2
# appet           1
# pe              1
# ane             1
# class           0
# dtype: int64

# %%
kd.drop('Unnamed: 0',inplace=True,axis=1)
kd.replace('?',np.nan,inplace=True)

# %%
kd_dat=kd.drop('class',axis=1)
kd_tgt=kd['class']

# %%
kd_dat.dtypes
# Out:
# age      object
# bp       object
# sg       object
# al       object
# su       object
# bgr      object
# bu       object
# sc       object
# sod      object
# pot      object
# hemo     object
# pcv      object
# wc       object
# rc       object
# rbc      object
# pc       object
# pcc      object
# ba       object
# htn      object
# dm       object
# cad      object
# appet    object
# pe       object
# ane      object
# dtype: object

# %%
kd_dat.dtypes
# Out:
# age      object
# bp       object
# sg       object
# al       object
# su       object
# bgr      object
# bu       object
# sc       object
# sod      object
# pot      object
# hemo     object
# pcv      object
# wc       object
# rc       object
# rbc      object
# pc       object
# pcc      object
# ba       object
# htn      object
# dm       object
# cad      object
# appet    object
# pe       object
# ane      object
# dtype: object

# %%
kd_dat[['age','bp','sg','al','su','pot','hemo','pcv','wc','rc','rbc','pc','pcc','ba']]=kd_dat[['age','bp','sg','al','su','pot','hemo','pcv','wc','rc','rbc','pc','pcc','ba']].astype('float')
kd_dat=pd.get_dummies(kd_dat,drop_first=True)

# %%
kd_dat.head()
# Out:
#     age    bp     sg   al   su    pot  hemo  pcv     wc   rc   ...     \
# 0  48.0  80.0  1.020  1.0  0.0  121.0  36.0  1.2    NaN  NaN   ...
# 1   7.0  50.0  1.020  4.0  0.0    NaN  18.0  0.8    NaN  NaN   ...
# 2  62.0  80.0  1.010  2.0  3.0  423.0  53.0  1.8    NaN  NaN   ...
# 3  48.0  70.0  1.005  4.0  0.0  117.0  56.0  3.8  111.0  2.5   ...
# 4  51.0  80.0  1.010  2.0  0.0  106.0  26.0  1.4    NaN  NaN   ...
#
#    bu_normal  sc_present  sod_present  htn_yes  dm_no  dm_yes  cad_yes  \
# 0          1           0            0        1      0       1        0
# 1          1           0            0        0      1       0        0
# 2          1           0            0        0      0       1        0
# 3          0           1            0        1      1       0        0
# 4          1           0            0        0      1       0        0
#
#    appet_poor  pe_yes  ane_yes
# 0           0       0        0
# 1           0       0        0
# 2           1       0        1
# ...

# %%
kd_tgt=pd.get_dummies(kd_tgt,drop_first=True)

# %%
kd_tgt.head()
# Out:
#    notckd
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0

# %%
dtrain,dtest,ltrain,ltest=train_test_split(kd_dat,kd_tgt,test_size=0.3,random_state=29)

# %% [markdown]
# # Logistic Regression

# %%
steps=[
    ('imp',Imputer(missing_values=np.nan,axis=0,strategy='mean')),
    ('scale',StandardScaler()),
    ('log',LogisticRegression())
]
pipeline=Pipeline(steps)
pipeline.fit(dtrain,ltrain)
pipeline.score(dtest,ltest)
# Out:
# /home/alphrho/anaconda3/lib/python3.6/site-packages/sklearn/utils/validation.py:578: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# 0.975

# %%
steps=[
    ('imp',Imputer(missing_values=np.nan,axis=0,strategy='median')),
    ('scale',StandardScaler()),
    ('log',LogisticRegression())
]
pipeline=Pipeline(steps)
pipeline.fit(dtrain,ltrain)
pipeline.score(dtest,ltest)
# Out:
# /home/alphrho/anaconda3/lib/python3.6/site-packages/sklearn/utils/validation.py:578: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# 0.9916666666666667

# %%
steps=[
    ('imp',Imputer(missing_values=np.nan,axis=0,strategy='most_frequent')),
    ('scale',StandardScaler()),
    ('log',LogisticRegression())
]
pipeline=Pipeline(steps)
pipeline.fit(dtrain,ltrain)
pipeline.score(dtest,ltest)
# Out:
# /home/alphrho/anaconda3/lib/python3.6/site-packages/sklearn/utils/validation.py:578: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# 1.0

# %% [markdown]
# # KNN

# %%
steps=[
    ('imp',Imputer(missing_values=np.nan,axis=0,strategy='mean')),
    ('scale',StandardScaler()),
    ('knn',KNeighborsClassifier(n_neighbors=5))
    ]
pipeline=Pipeline(steps)
pipeline.fit(dtrain,ltrain)
pipeline.score(dtest,ltest)
# Out:
# /home/alphrho/anaconda3/lib/python3.6/site-packages/sklearn/pipeline.py:250: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   self._final_estimator.fit(Xt, y, **fit_params)
# 1.0

# %% [markdown]
# # Decision Tree

# %%
steps=[
    ('imp',Imputer(missing_values=np.nan,axis=0,strategy='most_frequent')),
    ('scale',StandardScaler()),
    ('dtree',DecisionTreeClassifier(max_depth=20,min_samples_split=0.1,random_state=29))
    ]
pipeline=Pipeline(steps)
pipeline.fit(dtrain,ltrain)
pipeline.score(dtest,ltest)
# Out:
# 0.9916666666666667

# %%
steps=[
    ('imp',Imputer(missing_values=np.nan,axis=0,strategy='mean')),
    ('scale',StandardScaler()),
    ('dtree',DecisionTreeClassifier(max_depth=20,min_samples_split=0.1,random_state=29))
    ]
pipeline=Pipeline(steps)
pipeline.fit(dtrain,ltrain)
pipeline.score(dtest,ltest)
# Out:
# 0.975

# %%
steps=[
    ('imp',Imputer(missing_values=np.nan,axis=0,strategy='median')),
    ('scale',StandardScaler()),
    ('dtree',DecisionTreeClassifier(max_depth=20,min_samples_split=0.1,random_state=29))
    ]
pipeline=Pipeline(steps)
pipeline.fit(dtrain,ltrain)
pipeline.score(dtest,ltest)
# Out:
# 0.9666666666666667

# %% [markdown]
# # SVM

# %%
steps=[
    ('imp',Imputer(missing_values=np.nan,axis=0,strategy='mean')),
    ('scale',StandardScaler()),
    ('log',SVC())
]
pipeline=Pipeline(steps)
pipeline.fit(dtrain,ltrain)
pipeline.score(dtest,ltest)
# Out:
# /home/alphrho/anaconda3/lib/python3.6/site-packages/sklearn/utils/validation.py:578: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# 1.0

# %% [markdown]
# # XGBoost

# %%
steps=[
    ('gscv',xgb.XGBClassifier())
]

param_grid_g={
        'gscv__max_depth':[1,2,5,10,20],
        'gscv__learning_rate':[0.1,0.001,0.3,0.003,0.0001,0.0003],
        'gscv__n_estimators':[5,10,20,30,40]
    }

xgbpipe=Pipeline(steps)
#for i in range(2,20,2):
estim=GridSearchCV(xgbpipe,param_grid=param_grid_g,cv=3,verbose=1,scoring='neg_mean_squared_error')
estim.fit(dtrain,ltrain)
print(estim.best_params_)
print(np.sqrt(-1*estim.best_score_))
# Out:
# Fitting 3 folds for each of 150 candidates, totalling 450 fits
# /home/alphrho/anaconda3/lib/python3.6/site-packages/sklearn/preprocessing/label.py:95: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/alphrho/anaconda3/lib/python3.6/site-packages/sklearn/preprocessing/label.py:128: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/alphrho/anaconda3/lib/python3.6/site-packages/sklearn/preprocessing/label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# ...
